# %%
import numpy as np
import pandas as pd
import random

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
order = pd.read_csv('/home/felix/Downloads/orders.csv')
# Out:
# /home/felix/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (15,16,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
order.columns
# Out:
# Index(['akeed_order_id', 'customer_id', 'item_count', 'grand_total',
#        'payment_mode', 'promo_code', 'vendor_discount_amount',
#        'promo_code_discount_percentage', 'is_favorite', 'is_rated',
#        'vendor_rating', 'driver_rating', 'deliverydistance', 'preparationtime',
#        'delivery_time', 'order_accepted_time', 'driver_accepted_time',
#        'ready_for_pickup_time', 'picked_up_time', 'delivered_time',
#        'delivery_date', 'vendor_id', 'created_at', 'LOCATION_NUMBER',
#        'LOCATION_TYPE', 'CID X LOC_NUM X VENDOR'],
#       dtype='object')

# %%
order.shape
# Out:
# (135303, 26)

# %%
hy = order['CID X LOC_NUM X VENDOR']

# %%
hy = hy.drop_duplicates()

# %%
hy.shape
# Out:
# (80142,)

# %%
hy.value_counts()
# Out:
# P66OCMZ X 0 X 195    1
# GDJ5Q3V X 1 X 79     1
# V5EUZQT X 5 X 221    1
# JV3V0UL X 1 X 577    1
# LAQ989J X 2 X 197    1
# 9K33B7I X 1 X 86     1
# 6M6V4EF X 0 X 856    1
# TFO0E97 X 0 X 43     1
# KLT7AL8 X 0 X 161    1
# K7XV6Q7 X 3 X 259    1
# JFGJ8IG X 0 X 259    1
# 34517YM X 1 X 105    1
# IIPHXPF X 0 X 66     1
# 511TAJS X 0 X 106    1
# 3KHFH3E X 0 X 582    1
# CGUCESE X 0 X 85     1
# QXRNSE0 X 0 X 203    1
# ZWF27MA X 1 X 76     1
# 2SM6FIY X 0 X 78     1
# HA8KJN6 X 2 X 578    1
# GF5DIBK X 0 X 299    1
# N046NOU X 0 X 55     1
# R6ODDFJ X 1 X 537    1
# SLN9OXT X 0 X 4      1
# KNSNC27 X 0 X 243    1
# 20L1XC0 X 0 X 78     1
# NL5B4SZ X 1 X 547    1
# CJL8DZ0 X 1 X 401    1
# EDOGG5S X 0 X 386    1
# PZUIFGD X 0 X 195    1
#                     ..
# 0H20BYF X 1 X 295    1
# K22POF9 X 4 X 459    1
# 205VASC X 1 X 75     1
# 5PU6VVK X 2 X 84     1
# 5U33O4D X 2 X 92     1
# YSKIVGD X 1 X 44     1
# 5NZHWV4 X 4 X 681    1
# HF84FBJ X 0 X 294    1
# JL4YV8J X 1 X 154    1
# ...

# %%
order.dtypes
# Out:
# akeed_order_id                    float64
# customer_id                        object
# item_count                        float64
# grand_total                       float64
# payment_mode                        int64
# promo_code                         object
# vendor_discount_amount            float64
# promo_code_discount_percentage    float64
# is_favorite                        object
# is_rated                           object
# vendor_rating                     float64
# driver_rating                     float64
# deliverydistance                  float64
# preparationtime                   float64
# delivery_time                      object
# order_accepted_time                object
# driver_accepted_time               object
# ready_for_pickup_time              object
# picked_up_time                     object
# delivered_time                     object
# delivery_date                      object
# vendor_id                           int64
# ...

# %%
order = order[['akeed_order_id', 'customer_id', 'item_count', 'grand_total', 'payment_mode', 'vendor_discount_amount', 'promo_code_discount_percentage', 'is_favorite', 'is_rated', 'vendor_rating', 'driver_rating', 'deliverydistance', 'preparationtime', 'vendor_id', 'LOCATION_NUMBER', 'LOCATION_TYPE', 'CID X LOC_NUM X VENDOR']]

# %%
order.head(5)
# Out:
#    akeed_order_id customer_id  item_count  grand_total  payment_mode  \
# 0        163238.0     92PEE24         1.0          7.6             2
# 1        163240.0     QS68UD8         1.0          8.7             1
# 2        163241.0     MB7VY5F         2.0         14.4             1
# 3        163244.0     KDJ951Y         1.0          7.1             1
# 4        163245.0     BAL0RVT         4.0         27.2             1
#
#    vendor_discount_amount  promo_code_discount_percentage is_favorite  \
# 0                     0.0                             NaN         NaN
# 1                     0.0                             NaN         NaN
# 2                     0.0                             NaN         NaN
# 3                     0.0                             NaN         NaN
# 4                     0.0                             NaN         NaN
#
#   is_rated  vendor_rating  driver_rating  deliverydistance  preparationtime  \
# ...

# %%
order.shape
# Out:
# (135303, 17)

# %%
order.columns
# Out:
# Index(['akeed_order_id', 'customer_id', 'item_count', 'grand_total',
#        'payment_mode', 'vendor_discount_amount',
#        'promo_code_discount_percentage', 'is_favorite', 'is_rated',
#        'vendor_rating', 'driver_rating', 'deliverydistance', 'preparationtime',
#        'vendor_id', 'LOCATION_NUMBER', 'LOCATION_TYPE',
#        'CID X LOC_NUM X VENDOR'],
#       dtype='object')

# %%
duplicate_order = order[order.duplicated(['CID X LOC_NUM X VENDOR'])]
print(duplicate_order)
# Out:
#         akeed_order_id customer_id  item_count  grand_total  payment_mode  \
# 7             163248.0     I9DNSMJ         2.0         14.4             1
# 13            163257.0     DRR8CO9         2.0         11.4             1
# 57            163340.0     1WUPJGN         2.0         13.0             2
# 90            163407.0     FWNWSYH         1.0          7.6             1
# 136           163502.0     G5108U3         2.0         16.0             2
# 158           163541.0     OB15TZY         2.0          8.7             1
# 367           163956.0     II9FYLU         3.0          3.5             1
# 393           164026.0     CQMPL3W         2.0         10.1             1
# 406           164071.0     IFDT0BW         1.0          9.5             2
# 429           164122.0     QNZ8YW0         4.0         40.0             2
# 496           164262.0     N94XH2T         1.0         12.8             1
# 513           164301.0     D7GQVAR         2.0         24.3             1
# ...

# %%
order = order.drop_duplicates(['CID X LOC_NUM X VENDOR'])

# %%
order.shape
# Out:
# (80142, 17)

# %%
duplicate_order = order[order.duplicated(['customer_id', 'item_count', 'grand_total', 'payment_mode', 'vendor_discount_amount', 'promo_code_discount_percentage', 'is_favorite', 'is_rated', 'vendor_rating', 'driver_rating', 'deliverydistance', 'preparationtime', 'vendor_id', 'LOCATION_NUMBER', 'LOCATION_TYPE', 'CID X LOC_NUM X VENDOR'])]
print(duplicate_order)
# Out:
# Empty DataFrame
# Columns: [akeed_order_id, customer_id, item_count, grand_total, payment_mode, vendor_discount_amount, promo_code_discount_percentage, is_favorite, is_rated, vendor_rating, driver_rating, deliverydistance, preparationtime, vendor_id, LOCATION_NUMBER, LOCATION_TYPE, CID X LOC_NUM X VENDOR]
# Index: []

# %%
order = order.drop_duplicates(['customer_id', 'item_count', 'grand_total', 'payment_mode', 'vendor_discount_amount', 'promo_code_discount_percentage', 'is_favorite', 'is_rated', 'vendor_rating', 'driver_rating', 'deliverydistance', 'preparationtime', 'vendor_id', 'LOCATION_NUMBER', 'LOCATION_TYPE', 'CID X LOC_NUM X VENDOR'])

# %%
order.shape
# Out:
# (80142, 17)

# %%
order.head()
# Out:
#    akeed_order_id customer_id  item_count  grand_total  payment_mode  \
# 0        163238.0     92PEE24         1.0          7.6             2
# 1        163240.0     QS68UD8         1.0          8.7             1
# 2        163241.0     MB7VY5F         2.0         14.4             1
# 3        163244.0     KDJ951Y         1.0          7.1             1
# 4        163245.0     BAL0RVT         4.0         27.2             1
#
#    vendor_discount_amount  promo_code_discount_percentage is_favorite  \
# 0                     0.0                             NaN         NaN
# 1                     0.0                             NaN         NaN
# 2                     0.0                             NaN         NaN
# 3                     0.0                             NaN         NaN
# 4                     0.0                             NaN         NaN
#
#   is_rated  vendor_rating  driver_rating  deliverydistance  preparationtime  \
# ...

# %%
all_features = order


def percent_missing(df):
    data = pd.DataFrame(df)
    df__cols = list(pd.DataFrame(data))
    dict_x = {}
    for i in range(0, len(df_cols)):
        dict_x.update ({df_cols[i]: round(data[df_cols[i]].isnull().mean()*100, 2)})
    return  dict_x
df_cols = order.columns

missing = percent_missing(all_features)
df_miss = sorted(missing.items(), key=lambda x: x[1], reverse=True)

print('percent of missing data')
df_miss[0:17]
# Out:
# percent of missing data
# [('vendor_rating', 63.59),
#  ('promo_code_discount_percentage', 56.49),
#  ('preparationtime', 44.93),
#  ('LOCATION_TYPE', 38.4),
#  ('is_favorite', 26.41),
#  ('item_count', 5.52),
#  ('akeed_order_id', 0.02),
#  ('customer_id', 0.0),
#  ('grand_total', 0.0),
#  ('payment_mode', 0.0),
#  ('vendor_discount_amount', 0.0),
#  ('is_rated', 0.0),
#  ('driver_rating', 0.0),
#  ('deliverydistance', 0.0),
#  ('vendor_id', 0.0),
#  ('LOCATION_NUMBER', 0.0),
#  ('CID X LOC_NUM X VENDOR', 0.0)]

# %%
sns.set_style('white')
f, ax = plt.subplots(figsize=(8, 7))
sns.set_color_codes(palette='deep')
missing = round(order.isnull().mean()*100,2)
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar(color='b')

ax.xaxis.grid(False)
ax.set(ylabel='Percent of missing values')
ax.set(xlabel='Features')
ax.set(title='Percent of missing data')
sns.despine(trim=True, left=True)

# %%
order.dtypes
# Out:
# akeed_order_id                    float64
# customer_id                        object
# item_count                        float64
# grand_total                       float64
# payment_mode                        int64
# vendor_discount_amount            float64
# promo_code_discount_percentage    float64
# is_favorite                        object
# is_rated                           object
# vendor_rating                     float64
# driver_rating                     float64
# deliverydistance                  float64
# preparationtime                   float64
# vendor_id                           int64
# LOCATION_NUMBER                     int64
# LOCATION_TYPE                      object
# CID X LOC_NUM X VENDOR             object
# dtype: object

# %%
order['LOCATION_TYPE'].value_counts()
# Out:
# Home     29625
# Work     10262
# Other     9484
# Name: LOCATION_TYPE, dtype: int64

# %%
order['akeed_order_id'].value_counts()
# Out:
# 253208.0    2
# 251526.0    2
# 230638.0    2
# 230682.0    2
# 230686.0    2
# 251897.0    2
# 230684.0    2
# 252730.0    2
# 340215.0    1
# 404014.0    1
# 141645.0    1
# 383021.0    1
# 174414.0    1
# 239963.0    1
# 283295.0    1
# 283294.0    1
# 141644.0    1
# 251339.0    1
# 220409.0    1
# 263374.0    1
# 239307.0    1
# 138254.0    1
# 216676.0    1
# 207179.0    1
# 311598.0    1
# 174402.0    1
# 275232.0    1
# 234691.0    1
# 283271.0    1
# 340209.0    1
#            ..
# 388212.0    1
# 185450.0    1
# 305333.0    1
# 407186.0    1
# 305365.0    1
# 247469.0    1
# 218219.0    1
# 305367.0    1
# 313564.0    1
# 185452.0    1
# 152677.0    1
# 185444.0    1
# 263316.0    1
# 152675.0    1
# 414675.0    1
# 305334.0    1
# 125486.0    1
# 223442.0    1
# 370873.0    1
# 306670.0    1
# 250974.0    1
# 370877.0    1
# 250975.0    1
# 305345.0    1
# 229213.0    1
# 185441.0    1
# 400828.0    1
# 152674.0    1
# 256656.0    1
# 163840.0    1
# ...

# %%
def handl_miss(ord):
    ord['akeed_order_id'] = order['akeed_order_id'].interpolate()
    ord['item_count'] = order['item_count'].fillna(1)
    ord['is_favorite'] = order['is_favorite'].fillna('No')
    ord['LOCATION_TYPE'] = order['LOCATION_TYPE'].interpolate(method='pad')
    ord['preparationtime'] = order['preparationtime'].fillna(40)
    ord['promo_code_discount_percentage'] = order['promo_code_discount_percentage'].fillna(0)
    ord['vendor_rating'] = order['vendor_rating'].fillna(order['vendor_rating'].median())
    return ord

# %%
order = handl_miss(order)

# %%
missing = percent_missing(order)
df_miss = sorted(missing.items(), key=lambda x: x[1], reverse=True)
print('percent of missing data')
df_miss[0:17]
# Out:
# percent of missing data
# [('akeed_order_id', 0.0),
#  ('customer_id', 0.0),
#  ('item_count', 0.0),
#  ('grand_total', 0.0),
#  ('payment_mode', 0.0),
#  ('vendor_discount_amount', 0.0),
#  ('promo_code_discount_percentage', 0.0),
#  ('is_favorite', 0.0),
#  ('is_rated', 0.0),
#  ('vendor_rating', 0.0),
#  ('driver_rating', 0.0),
#  ('deliverydistance', 0.0),
#  ('preparationtime', 0.0),
#  ('vendor_id', 0.0),
#  ('LOCATION_NUMBER', 0.0),
#  ('LOCATION_TYPE', 0.0),
#  ('CID X LOC_NUM X VENDOR', 0.0)]

# %%
order['akeed_order_id'].value_counts()
# Out:
# 230686.0    2
# 253208.0    2
# 251526.0    2
# 230682.0    2
# 230638.0    2
# 251897.0    2
# 230684.0    2
# 252730.0    2
# 340215.0    1
# 404014.0    1
# 141645.0    1
# 383021.0    1
# 174414.0    1
# 239963.0    1
# 138254.0    1
# 283294.0    1
# 141644.0    1
# 283295.0    1
# 251339.0    1
# 220409.0    1
# 239307.0    1
# 414359.0    1
# 216676.0    1
# 207179.0    1
# 311598.0    1
# 174402.0    1
# 275232.0    1
# 234691.0    1
# 283271.0    1
# 340209.0    1
#            ..
# 185448.0    1
# 218217.0    1
# 277906.0    1
# 185450.0    1
# 407186.0    1
# 305365.0    1
# 247469.0    1
# 218219.0    1
# 305367.0    1
# 313564.0    1
# 185444.0    1
# 263316.0    1
# 152675.0    1
# 256656.0    1
# 305333.0    1
# 414675.0    1
# 305334.0    1
# 125486.0    1
# 223442.0    1
# 370873.0    1
# 306670.0    1
# 250974.0    1
# 370877.0    1
# 250975.0    1
# 305345.0    1
# 229213.0    1
# 185441.0    1
# 400828.0    1
# 152674.0    1
# 163840.0    1
# ...

# %%
order.dtypes
# Out:
# akeed_order_id                    float64
# customer_id                        object
# item_count                        float64
# grand_total                       float64
# payment_mode                        int64
# vendor_discount_amount            float64
# promo_code_discount_percentage    float64
# is_favorite                        object
# is_rated                           object
# vendor_rating                     float64
# driver_rating                     float64
# deliverydistance                  float64
# preparationtime                   float64
# vendor_id                           int64
# LOCATION_NUMBER                     int64
# LOCATION_TYPE                      object
# CID X LOC_NUM X VENDOR             object
# dtype: object

# %%
order['akeed_order_id'] = order['akeed_order_id'].astype(int)
order['item_count'] = order['item_count'].astype(int)
order['payment_mode'] = order['payment_mode'].astype('category')
order['is_favorite'] = order['is_favorite'].astype('category')
order['is_rated'] = order['is_rated'].astype('category')
order['vendor_id'] = order['vendor_id'].astype('category')
order['LOCATION_NUMBER'] = order['LOCATION_NUMBER'].astype('category')
order['LOCATION_TYPE'] = order['LOCATION_TYPE'].astype('category')

# %%
order.dtypes
# Out:
# akeed_order_id                       int64
# customer_id                         object
# item_count                           int64
# grand_total                        float64
# payment_mode                      category
# vendor_discount_amount             float64
# promo_code_discount_percentage     float64
# is_favorite                       category
# is_rated                          category
# vendor_rating                      float64
# driver_rating                      float64
# deliverydistance                   float64
# preparationtime                    float64
# vendor_id                         category
# LOCATION_NUMBER                   category
# LOCATION_TYPE                     category
# CID X LOC_NUM X VENDOR              object
# dtype: object

# %%
order.head()
# Out:
#    akeed_order_id customer_id  item_count  grand_total payment_mode  \
# 0          163238     92PEE24           1          7.6            2
# 1          163240     QS68UD8           1          8.7            1
# 2          163241     MB7VY5F           2         14.4            1
# 3          163244     KDJ951Y           1          7.1            1
# 4          163245     BAL0RVT           4         27.2            1
#
#    vendor_discount_amount  promo_code_discount_percentage is_favorite  \
# 0                     0.0                             0.0          No
# 1                     0.0                             0.0          No
# 2                     0.0                             0.0          No
# 3                     0.0                             0.0          No
# 4                     0.0                             0.0          No
#
#   is_rated  vendor_rating  driver_rating  deliverydistance  preparationtime  \
# ...

# %%
order['CID X LOC_NUM X VENDOR'].value_counts()
# Out:
# LMIB9T1 X 2 X 575    1
# GYDGFFJ X 0 X 85     1
# B9WMW6N X 0 X 149    1
# HDW7QPY X 0 X 386    1
# WJN75GZ X 0 X 289    1
# BNZ75P7 X 0 X 193    1
# 1LZAGNZ X 1 X 577    1
# ZZJSJYC X 0 X 271    1
# T5V0NYA X 1 X 537    1
# 7T2JR6M X 0 X 104    1
# MAFLLWT X 1 X 159    1
# EB6G5XE X 1 X 575    1
# 8PBQKLH X 0 X 300    1
# C9JPX95 X 1 X 676    1
# 30FA6JH X 0 X 386    1
# FRBAFP4 X 4 X 92     1
# JKDC9XL X 1 X 86     1
# JRVM3EO X 1 X 459    1
# JU554BP X 2 X 86     1
# 8GR8D4Q X 1 X 295    1
# 0YMPZLT X 0 X 90     1
# 3IHFZG9 X 0 X 386    1
# IAVE0AF X 0 X 85     1
# FINZB1J X 1 X 583    1
# NWNWQWW X 1 X 105    1
# FY7T803 X 1 X 104    1
# TMGFF99 X 5 X 81     1
# WYJVRX8 X 0 X 78     1
# 141REOU X 1 X 104    1
# MAOM4IQ X 0 X 115    1
#                     ..
# SDQR5EC X 2 X 195    1
# 1VGJ69S X 0 X 134    1
# NX4LU4L X 0 X 113    1
# YU90KWF X 1 X 243    1
# HNYOE0U X 0 X 66     1
# 8U1O485 X 0 X 105    1
# JICF27K X 0 X 92     1
# ZZBPHU4 X 0 X 855    1
# FIC3GGQ X 4 X 855    1
# ...
